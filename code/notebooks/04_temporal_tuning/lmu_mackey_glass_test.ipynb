# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append('../../lib')
sys.path.append('../../chapters/04_temporal_tuning')

# %%
import lmu_mackey_glass
import lmu_utils

# %%
_, loss, traj, model = lmu_mackey_glass.run_single_experiment(((0, 0, 0), 6, False, False, 1), verbose=True, return_model=True)
loss
# Out:
# Epoch 1/100
# 400/400 [==============================] - 3s 7ms/step - loss: 0.2316 - val_loss: 0.0612
# Epoch 2/100
# 400/400 [==============================] - 3s 6ms/step - loss: 0.0357 - val_loss: 0.0483
# Epoch 3/100
# 400/400 [==============================] - 3s 6ms/step - loss: 0.0280 - val_loss: 0.0413
# Epoch 4/100
# 400/400 [==============================] - 3s 6ms/step - loss: 0.0252 - val_loss: 0.0375
# Epoch 5/100
# 400/400 [==============================] - 3s 6ms/step - loss: 0.0231 - val_loss: 0.0347
# Epoch 6/100
# 400/400 [==============================] - 2s 6ms/step - loss: 0.0222 - val_loss: 0.0324
# Epoch 7/100
# 400/400 [==============================] - 3s 6ms/step - loss: 0.0205 - val_loss: 0.0296
# Epoch 8/100
# 400/400 [==============================] - 2s 6ms/step - loss: 0.0188 - val_loss: 0.0317
# Epoch 9/100
# 400/400 [==============================] - 3s 6ms/step - loss: 0.0179 - val_loss: 0.0259
# Epoch 10/100
# ...
