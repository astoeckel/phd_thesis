# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys, os
sys.path.append("../lib/")

# %%
import lif_utils
import matplotlib.pyplot as plt
import numpy as np

# %%
Js = np.linspace(0, 3e-9, 1024)
As = lif_utils.lif_detailed_rate(Js)
fig, ax = plt.subplots()
ax.plot(Js, As)

# %%
Js = np.linspace(0, 3e-9, 1024)
As = lif_utils.lif_detailed_rate(Js)
Js_rec = lif_utils.lif_detailed_rate_inv(As)
fig, ax = plt.subplots()
ax.plot(Js, Js)
ax.plot(Js, Js_rec)
