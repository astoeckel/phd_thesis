# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import h5py
import numpy as np
import matplotlib.pyplot as plt

import os, sys
sys.path.append("../../lib")

# %%
import two_comp_approx_2d_fun

# %%
two_comp_approx_2d_fun.run_single_experiment_common(1.0, 1e-3, "gc50_no_noise", 30)
# Out:
# WARN: Error while computing weights for post-neuron 0. Maximum number of iterations reached.
# (0.3364613654150878, 0.35857569022774116)
